# %% [markdown]
# # **Explanatory Analysis of the GoFord Bike System Data**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Importing the cleaned dataset

df = pd.read_csv(r'C:\Users\ilesanmi\Desktop\Udacity\Vis Proj\cleaned_data.csv')

# %%
df.sample(3)
# Out:
#         duration_sec               start_time                 end_time  \
# 180195           522  2019-02-01 11:11:59.617  2019-02-01 11:20:42.568
# 119837           466  2019-02-11 17:24:49.762  2019-02-11 17:32:35.921
# 87690            954  2019-02-16 22:05:55.030  2019-02-16 22:21:49.833
#
#         start_station_id       start_station_name  start_station_latitude  \
# 180195              16.0  Steuart St at Market St                37.79413
# 119837              19.0     Post St at Kearny St                37.78898
# 87690              254.0  Vine St at Shattuck Ave                37.88022
#
#         start_station_longitude  end_station_id  \
# 180195               -122.39443             6.0
# 119837               -122.40345            62.0
# 87690                -122.26959           243.0
#
#                      end_station_name  end_station_latitude  ...  bike_id  \
# 180195  The Embarcadero at Sansome St              37.80477  ...     5424
# 119837    Victoria Manalo Draves Park              37.77779  ...      477
# 87690     Bancroft Way at College Ave              37.86936  ...     4483
#
#          user_type member_birth_year  member_gender bike_share_for_all_trip  \
# 180195  Subscriber              1982           Male                      No
# 119837    Customer              1984           Male                      No
# 87690   Subscriber              1996         Female                      No
#
#        member_age  start_hour  day_time end_hour  return_time
# 180195         37          11   morning       11      morning
# 119837         35          17   evening       17      evening
# 87690          23          22     night       22        night
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Analysis goes thus:

# %% [markdown]
# # **The most common Gender that makes use of the bike**

# %%
df.member_gender.value_counts().plot(kind = 'barh');
plt.title('Gender count')
plt.ylabel('Gender')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %%
# It so happens that the male Gender happens to be more interested in biking than femmales

# %% [markdown]
# # **What time of the day do we have most rides**

# %%
df['day_time'].value_counts().plot(kind = 'barh');
plt.title('day time people bike')
plt.xlabel('Count')
plt.ylabel('Time of the day')
# Out:
# Text(0, 0.5, 'Time of the day')

# %% [markdown]
# ##### During the day, there are more trips in the morning and afternoon than at night. It probably because of rush hours. There are more rides in the afternoon... this i believe is cause of students who return frm school and goes biking. And then, at night, peeps tend return home

# %% [markdown]
# ### **IS there ever a time of the day women bike more than men?**

# %%
sns.countplot(data= df, x = 'day_time', hue = 'member_gender')


plt.title('day time people bike')
plt.ylabel('Count')
plt.xlabel('Gender based bike count')
# Out:
# Text(0, 0.5, 'Time of the day')

# %% [markdown]
# ##### IT is clear that though male still bikes more, morning and evening still is the time with the most biking

# %% [markdown]
# ### **What particular hour of the day do we have most biking**

# %%
plt.figure(figsize = (12,8))
df.start_hour.value_counts().plot(kind = 'bar')
plt.title('Hours people bike mostly')
plt.xlabel('Hours')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 17pm and 8am are active going to work times. So we can infer that most people who bike do so cause of their transportation to and back from work

# %% [markdown]
# ### **Compare the return time and the start time biking**

# %%
plt.figure(figsize = (12,8))
plt.subplot(1,2,1)
df['day_time'].value_counts().plot(kind = 'barh');
plt.title('day time people bike')

plt.subplot(1,2,2)
df['return_time'].value_counts().plot(kind = 'barh');
plt.title('return time people bike')
# Out:
# Text(0.5, 1.0, 'return time people bike')

# %%
df['day_time'].value_counts(), df['return_time'].value_counts()
# Out:
# (morning      70404
#  evening      52809
#  afternoon    34536
#  night        25465
#  Name: day_time, dtype: int64,
#  morning      68896
#  evening      52679
#  afternoon    34068
#  night        27571
#  Name: return_time, dtype: int64)

# %% [markdown]
# #### stll about the same thing

# %% [markdown]
# ### **What usertype use the biking system mostly**

# %%
df['user_type'].value_counts().plot(kind = 'bar')
plt.title('Bike user types')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### **is there ever a time the customers used it more**

# %%
sns.countplot(data= df, x = 'day_time', hue = 'user_type')


plt.title('day time people bike')
plt.ylabel('Count')
plt.xlabel('Gender based bike count')
# Out:
# Text(0.5, 0, 'Gender based bike count')

# %% [markdown]
# #### This chart shows that a good number of customer usertype uses the bike in the afternoon. Unlike the normal chat flow... there's no drop in usage for the afternoon ride for the customer usertype

# %% [markdown]
# ## **Top ten stations**
# **Start station**

# %%
top10 = ['Market St at 10th St','San Francisco Caltrain Station 2  (Townsend St at 4th St)','Berry St at 4th St','Montgomery St BART Station (Market St at 2nd St)','Powell St BART Station (Market St at 4th St)'
,'San Francisco Ferry Building (Harry Bridges Plaza)','San Francisco Caltrain (Townsend St at 4th St)', 'Powell St BART Station (Market St at 5th St)','Howard St at Beale St','Steuart St at Market St']

df_top_ten = df.loc[df['start_station_name'].isin(top10)]

#df_top_ten
st_stat_order = df_top_ten['start_station_name'].value_counts().index

base_color = sns.color_palette()[0]
sns.countplot(data=df_top_ten, y='start_station_name', color=base_color, order=st_stat_order, )
plt.xlabel('Count')
plt.ylabel('Start Station Name')
plt.title('Top 8 Stations with the most trips in SF');

# %%
df['start_station_name'].value_counts().nlargest(10)
# Out:
# Market St at 10th St                                         3904
# San Francisco Caltrain Station 2  (Townsend St at 4th St)    3544
# Berry St at 4th St                                           3052
# Montgomery St BART Station (Market St at 2nd St)             2895
# Powell St BART Station (Market St at 4th St)                 2760
# San Francisco Ferry Building (Harry Bridges Plaza)           2709
# San Francisco Caltrain (Townsend St at 4th St)               2703
# Powell St BART Station (Market St at 5th St)                 2327
# Howard St at Beale St                                        2293
# Steuart St at Market St                                      2283
# Name: start_station_name, dtype: int64

# %% [markdown]
# ### **checking for the endstation**

# %%
df['end_station_name'].value_counts().nlargest(10)
# Out:
# San Francisco Caltrain Station 2  (Townsend St at 4th St)    4857
# Market St at 10th St                                         3973
# Montgomery St BART Station (Market St at 2nd St)             3647
# San Francisco Ferry Building (Harry Bridges Plaza)           3368
# Powell St BART Station (Market St at 4th St)                 2997
# San Francisco Caltrain (Townsend St at 4th St)               2947
# Berry St at 4th St                                           2872
# The Embarcadero at Sansome St                                2512
# Powell St BART Station (Market St at 5th St)                 2353
# Steuart St at Market St                                      2338
# Name: end_station_name, dtype: int64

# %%
top10 = ['San Francisco Caltrain Station 2  (Townsend St at 4th St)','Market St at 10th St','Montgomery St BART Station (Market St at 2nd St)','San Francisco Ferry Building (Harry Bridges Plaza)','Powell St BART Station (Market St at 4th St)',
'San Francisco Caltrain (Townsend St at 4th St)','Berry St at 4th St','The Embarcadero at Sansome St','Powell St BART Station (Market St at 5th St)','Steuart St at Market St']

df_top_ten_2 = df.loc[df['end_station_name'].isin(top10)]

#df_top_ten
st_stat_order = df_top_ten_2['end_station_name'].value_counts().index

base_color = sns.color_palette()[0]
sns.countplot(data=df_top_ten_2, y='end_station_name', color=base_color, order=st_stat_order)
plt.xlabel('Count')
plt.ylabel('End Station Name')
plt.title('Top 8 Stations with the most trips in SF');

# %% [markdown]
# ####
# * San Francisco Caltrain Station 2  (Townsend St at 4th St) seems to be a veery busy place. It tops the return location and seconds the start_ride_location

# %% [markdown]
# ## **IS there any correlation between duration and age?**

# %%
plt.figure(figsize=(12,7))
plt.scatter(df.member_age,df.duration_sec, alpha = 0.4)
plt.xlabel('member age')
plt.ylabel('duration sec')
plt.title('retlationship between ride duration and age')
# Out:
# Text(0.5, 1.0, 'retlationship between ride duration and age')

# %% [markdown]
# ###
# * This looks like ther's a **slight** negative correlation

# %%
plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
sns.distplot(df['member_age']);
plt.title('member age')
plt.xlabel('age')

plt.subplot(1,2,2)
bb = np.arange(15, df['member_age'].mean()+20, 5)
plt.hist(df['member_age'], bins = bb);
plt.title('member age')
plt.xlabel('age')
plt.show()
# Out:
# c:\Users\ilesanmi\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### We can see a good number of people are within the age 20 and 45. Lets see the correlation better within that age bracket

# %%
active_ages = df.query('member_age > 20 & member_age<45')
#active_ages
plt.figure(figsize = (12,5))

plt.scatter(active_ages['member_age'], active_ages['duration_sec'])
plt.xlabel('member age between 20 and 45')
plt.ylabel('duration sec')
plt.title('retlationship between ride duration and age within 20 and 45')
# Out:
# Text(0.5, 1.0, 'retlationship between ride duration and age within 20 and 45')

# %% [markdown]
# ###
#  * So aside the unique duration at age 34 and 30, the slight negative correlation can be seen

# %% [markdown]
# ## **Amongst the top 10, what are their number of trips**
# **start station**

# %%
day_times = ['morning', 'afternoon', 'evening', 'night']


day_times = pd.api.types.CategoricalDtype(ordered=True, categories=day_times)

# Use pandas.astype() to convert the "VClass" column from a plain object type into an ordered categorical type 
df_top_ten['day_time'] = df_top_ten['day_time'].astype(day_times)
# Out:
# <ipython-input-43-c76d643e1a30>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top_ten['day_time'] = df_top_ten['day_time'].astype(day_times)

# %%
fig = plt.figure(figsize=(8,10))
#plt.subplots_adjust(top=0.95)
fig.suptitle('Count of trips for each day time', fontsize=14)


sns.countplot(data=df_top_ten, y='start_station_name', hue='day_time')
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
plt.ylabel('Start Station Name')
plt.xlabel('Count');

# %% [markdown]
# ###
# **End station**

# %%
fig = plt.figure(figsize=(8,10))
#plt.subplots_adjust(top=0.95)
fig.suptitle('Count of trips for each day time', fontsize=14)


sns.countplot(data=df_top_ten, y='start_station_name', hue='return_time')
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
plt.ylabel('Start Station Name')
plt.xlabel('Count');

# %%
###

# %%
g = sns.FacetGrid(data = df_top_ten, col = 'day_time', size = 7 );
g.map(sns.countplot, 'start_station_name');
g.set_xticklabels(rotation = 90, fontsize = 15)
g.set_titles('number of rides per day_time and for the top 10 stations')
plt.show()
# Out:
# c:\Users\ilesanmi\Anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# c:\Users\ilesanmi\Anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## **What is the average age of the member_age**

# %%
df.groupby('member_gender')['member_age'].mean().plot(kind = 'bar')
plt.title('average age for the gender')
plt.ylabel('count')
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
df.groupby('member_gender')['member_age'].describe()
# Out:
#                   count       mean        std   min   25%   50%   75%    max
# member_gender
# Female          40804.0  33.221057   9.268773  18.0  27.0  31.0  37.0  119.0
# Male           130500.0  34.453617  10.345189  18.0  27.0  32.0  39.0  119.0
# Other            3647.0  35.897998  10.098447  19.0  29.0  34.0  40.0  109.0

# %% [markdown]
# ###
# * by this, the average age are almost same... and by looking into the statistics, there are ranges in the ages of each gender, but their average still comes close

# %%
#!jupyter nbconvert 'Explanation slide with FordGo Bike system Data' --to slides --post serve
#jupyter nbconvert
# Out:
#   File "<ipython-input-6-8e90e578ac9e>", line 2
#     jupyter nbconvert
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### **Summative analysis** shows that more rides are taken at morning and also in the evening. So I assumed that most of the people who make use of this service are working class.
#
# #### Also, we have more of males than female who makes use of this services. This could be that many women are not bikers, hence the lesser amount of their usage
#
# #### There's a slight negative correlation betweeen ride duration and age. Though there are times we have exceptional increase. But there are more rides at the lower ages than at the higher ages
